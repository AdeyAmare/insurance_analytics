# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import sys
import os

sns.set_style("whitegrid")

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)


from src.eda import InsuranceEDA
from src.cleaner import DataCleaner
from src.eda_visualizations import InsuranceEDAVisualizer

# %%
DATA_FILE_PATH = '../data/MachineLearningRating_cleaned.txt'
DELIMITER = '|'

# %%
data_cleaner = DataCleaner(DATA_FILE_PATH, DELIMITER)
df_cleaned = data_cleaner.load_data()
df_cleaned = data_cleaner.data_conversion()
# Out:
# Loading data from '../data/MachineLearningRating_cleaned.txt'...
# Data loaded: 1000098 rows, 50 columns.
# Converted 'TransactionMonth' to datetime.
# Converted 'VehicleIntroDate' to datetime.

# %%
df_cleaned.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
# 3               145255     12827       2015-05-01             True
# 4               145255     12827       2015-07-01             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# 0  Current account  ...             Mobility - Windscreen    Windscreen
# 1  Current account  ...             Mobility - Windscreen    Windscreen
# 2  Current account  ...             Mobility - Windscreen    Windscreen
# 3  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
# 4  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#    TotalPremium TotalClaims
# 0     21.929825         0.0
# 1     21.929825         0.0
# 2      0.000000         0.0
# 3    512.848070         0.0
# 4      0.000000         0.0
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
eda = InsuranceEDA(df_cleaned)
results = eda.run()
# Out:
# c:\Users\amare\Documents\KAIM\week-3\insurance_analytics\src\eda.py:72: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample("M")

# %%
print("1️⃣ Numeric Summary Statistics:")
display(results["numeric_summary"])
# Out:
# 1️⃣ Numeric Summary Statistics:
#                               count          mean           std           min  \
# UnderwrittenCoverID       1000098.0  1.048175e+05  6.329371e+04  1.000000e+00
# PolicyID                  1000098.0  7.956682e+03  5.290039e+03  1.400000e+01
# PostalCode                1000098.0  3.020601e+03  2.649854e+03  1.000000e+00
# mmcode                     999546.0  5.487770e+07  1.360381e+07  4.041200e+06
# RegistrationYear          1000098.0  2.010225e+03  3.261391e+00  1.987000e+03
# Cylinders                  999546.0  4.046642e+00  2.940201e-01  0.000000e+00
# cubiccapacity              999546.0  2.466743e+03  4.428006e+02  0.000000e+00
# kilowatts                  999546.0  9.720792e+01  1.939326e+01  0.000000e+00
# NumberOfDoors              999546.0  4.019250e+00  4.683144e-01  0.000000e+00
# CustomValueEstimate        220456.0  2.255311e+05  5.645157e+05  2.000000e+04
# SumInsured                1000098.0  6.041727e+05  1.508332e+06  1.000000e-02
# CalculatedPremiumPerTerm  1000098.0  1.178757e+02  3.997017e+02  0.000000e+00
# TotalPremium              1000098.0  6.190550e+01  2.302845e+02 -7.825768e+02
# TotalClaims               1000098.0  6.486119e+01  2.384075e+03 -1.200241e+04
#
#                                    25%           50%           75%  \
# UnderwrittenCoverID       5.514300e+04  9.408300e+04  1.391900e+05
# PolicyID                  4.500000e+03  7.071000e+03  1.107700e+04
# PostalCode                8.270000e+02  2.000000e+03  4.180000e+03
# mmcode                    6.005692e+07  6.005842e+07  6.005842e+07
# RegistrationYear          2.008000e+03  2.011000e+03  2.013000e+03
# Cylinders                 4.000000e+00  4.000000e+00  4.000000e+00
# cubiccapacity             2.237000e+03  2.694000e+03  2.694000e+03
# kilowatts                 7.500000e+01  1.110000e+02  1.110000e+02
# NumberOfDoors             4.000000e+00  4.000000e+00  4.000000e+00
# CustomValueEstimate       1.350000e+05  2.200000e+05  2.800000e+05
# SumInsured                5.000000e+03  7.500000e+03  2.500000e+05
# CalculatedPremiumPerTerm  3.224800e+00  8.436900e+00  9.000000e+01
# TotalPremium              0.000000e+00  2.178333e+00  2.192982e+01
# TotalClaims               0.000000e+00  0.000000e+00  0.000000e+00
#
#                                    max         CV
# UnderwrittenCoverID       3.011750e+05   0.603847
# PolicyID                  2.324600e+04   0.664855
# PostalCode                9.870000e+03   0.877261
# mmcode                    6.506535e+07   0.247893
# RegistrationYear          2.015000e+03   0.001622
# Cylinders                 1.000000e+01   0.072658
# cubiccapacity             1.288000e+04   0.179508
# kilowatts                 3.090000e+02   0.199503
# NumberOfDoors             6.000000e+00   0.116518
# CustomValueEstimate       2.655000e+07   2.503050
# SumInsured                1.263620e+07   2.496524
# CalculatedPremiumPerTerm  7.442217e+04   3.390875
# TotalPremium              6.528260e+04   3.719936
# TotalClaims               3.930921e+05  36.756567

# %%
# ----------------------------
# 2. Categorical Summary
# ----------------------------
print("\n2️⃣ Categorical Summary (top 10 values per column):")
for col, counts in results["categorical_summary"].items():
    print(f"\n{col}:")
    display(counts)
# Out:
# 2️⃣ Categorical Summary (top 10 values per column):
#
# Citizenship:
# Citizenship
#       895210
# ZA    103721
# ZW       936
# AF       231
# Name: count, dtype: int64
# LegalType:
# LegalType
# Individual           911929
# Private company       83891
# Close Corporation      2459
# Public company         1295
# Partnership             331
# Sole proprieter         193
# Name: count, dtype: int64
# Title:
# Title
# Mr      933555
# Mrs      45850
# Ms       13269
# Miss      6614
# Dr         810
# Name: count, dtype: int64
# Language:
# Language
# English    1000098
# Name: count, dtype: int64
# Bank:
# Bank
# First National Bank    260811
# ABSA Bank              204954
# Standard Bank          181715
# Nedbank                132003
# Capitec Bank            58155
# RMB Private Bank        12576
# Ithala Bank              1730
# Investec Bank             732
# Old Mutual                688
# FirstRand Bank            638
# Name: count, dtype: int64
# AccountType:
# AccountType
# Current account         597938
# Savings account         358207
# Transmission account      3721
# Name: count, dtype: int64
# MaritalStatus:
# MaritalStatus
# Not specified    986208
# Single             4254
# Married            1377
# Name: count, dtype: int64
# Gender:
# Gender
# Not specified    940990
# Male              42817
# Female             6755
# Name: count, dtype: int64
# Country:
# Country
# South Africa    1000098
# Name: count, dtype: int64
# Province:
# Province
# Gauteng          393865
# Western Cape     170796
# KwaZulu-Natal    169781
# North West       143287
# Mpumalanga        52718
# Eastern Cape      30336
# Limpopo           24836
# Free State         8099
# Northern Cape      6380
# Name: count, dtype: int64
# MainCrestaZone:
# MainCrestaZone
# Transvaal (all except Pretoria)                296187
# Johannesburg                                   176020
# Transvaal (Pretoria)                           100331
# Cape Province (Cape Town)                       95936
# Natal                                           88266
# Natal (Durban)                                  82859
# Karoo 1 (Northeast of Cape Town)                52732
# Rand East                                       42168
# Tembu 2, Cape Mid 2, Cape Mid West, Tembu 1     20191
# Cape Province (East and North of Cape Town)     19391
# Name: count, dtype: int64
# SubCrestaZone:
# SubCrestaZone
# Johannesburg            176020
# Pretoria                100331
# Cape Town                95936
# Durban                   82859
# Transvaal North          75141
# Transvaal North West     72558
# Northeast of CT          51386
# Transvaal East           45729
# Transvaal South          45571
# Rand East                42168
# Name: count, dtype: int64
# ItemType:
# ItemType
# Mobility - Motor    1000098
# Name: count, dtype: int64
# VehicleType:
# VehicleType
# Passenger Vehicle    933598
# Medium Commercial     53985
# Heavy Commercial       7401
# Light Commercial       3897
# Bus                     665
# Name: count, dtype: int64
# make:
# make
# TOYOTA                                 813280
# MERCEDES-BENZ                           41940
# CMC                                     21624
# VOLKSWAGEN                              20929
# C.A.M                                   16171
# GOLDEN JOURNEY                          14462
# NISSAN/DATSUN                           10997
# JINBEI                                  10374
# IVECO                                    8430
# AUDI                                     7407
# Name: count, dtype: int64
# Model:
# Model
# QUANTUM 2.7 SESFIKILE 16s         186087
# QUANTUM 2.7 SESFIKILE 15s         167523
# QUANTUM 2.7 SESFIKILE 14s         137242
# QUANTUM 2.5 D-4D SESFIKILE 16s     99444
# HiACE SUPER 16 F/Lift              79525
# HiACE SIYAYA                       40960
# QUANTUM 2.5 D-4D 14 SEAT           28773
# AMANDLA 2.2                        16821
# AVANZA 1.5 SX                      15828
# INYATHI                            11265
# Name: count, dtype: int64
# bodytype:
# bodytype
# B/S    844400
# P/V     55034
# S/D     41868
# MPV     33842
# C/C      8861
# H/B      8400
# S/W      3100
# SUV      2049
# S/C       880
# C/P       644
# Name: count, dtype: int64
# AlarmImmobiliser:
# AlarmImmobiliser
# Yes    999861
# No        237
# Name: count, dtype: int64
# TrackingDevice:
# TrackingDevice
# No     656617
# Yes    343481
# Name: count, dtype: int64
# CapitalOutstanding:
# CapitalOutstanding
# 0         779482
# 0.00       13298
# 125000      4130
# 232500      3972
# 329500      3923
# 250500      3225
# 130000      3218
# 218000      2954
# 330000      2949
# 220000      2927
# Name: count, dtype: int64
# NewVehicle:
# NewVehicle
# More than 6 months    845223
# Less than 6 months      1580
# Name: count, dtype: int64
# WrittenOff:
# WrittenOff
# No     358165
# Yes        32
# Name: count, dtype: int64
# Rebuilt:
# Rebuilt
# No     358165
# Yes        32
# Name: count, dtype: int64
# Converted:
# Converted
# No     358110
# Yes        87
# Name: count, dtype: int64
# TermFrequency:
# TermFrequency
# Monthly    999554
# Annual        544
# Name: count, dtype: int64
# ExcessSelected:
# ExcessSelected
# No excess                                                         791235
# Mobility - Windscreen                                              97313
# Mobility - Taxi with value more than R100 000 - R5 000             76424
# Mobility - Taxi with value less than R100 000 - R3 000             15249
# Mobility - Metered Taxis - R2000                                    6999
# Mobility - Windscreen (Feb2015)                                     6450
# Mobility - Taxi with value more than R100 000 - R5 000 (April)      3022
# Mobility - Metered Taxis - R5000                                    1704
# Mobility - Taxi with value more than R100 000 - R10 000             1108
# Mobility - R250                                                      463
# Name: count, dtype: int64
# CoverCategory:
# CoverCategory
# Passenger Liability                        104158
# Third Party                                102825
# Keys and Alarms                            102428
# Signage and Vehicle Wraps                  102416
# Emergency Charges                          102416
# Cleaning and Removal of Accident Debris    102414
# Windscreen                                  97313
# Own Damage                                  78981
# Income Protector                            60001
# Basic Excess Waiver                         53755
# Name: count, dtype: int64
# CoverType:
# CoverType
# Own Damage                                 104183
# Passenger Liability                        104158
# Windscreen                                 103763
# Third Party                                102825
# Keys and Alarms                            102428
# Signage and Vehicle Wraps                  102416
# Emergency Charges                          102416
# Cleaning and Removal of Accident Debris    102414
# Income Protector                            64813
# Basic Excess Waiver                         57769
# Name: count, dtype: int64
# CoverGroup:
# CoverGroup
# Comprehensive - Taxi              824124
# Income Protector                   64813
# Basic Excess Waiver                57769
# Accidental Death                   27321
# Credit Protection                  18070
# Motor Comprehensive                 3941
# Deposit Cover                       1299
# Asset Value Preserver                865
# Fire,Theft and Third Party           750
# Standalone passenger liability       544
# Name: count, dtype: int64
# Section:
# Section
# Motor Comprehensive                                828125
# Optional Extended Covers                           152530
# Credit Protection                                   18070
# Third party or third party, fire and theft only       829
# Standalone passenger liability                        544
# Name: count, dtype: int64
# Product:
# Product
# Mobility Commercial Cover: Monthly    915028
# Mobility Metered Taxis: Monthly        79272
# Bridge Taxi Finance: Monthly            5254
# Standalone Passenger Liability           544
# Name: count, dtype: int64
# StatutoryClass:
# StatutoryClass
# Commercial    1000098
# Name: count, dtype: int64
# StatutoryRiskType:
# StatutoryRiskType
# IFRS Constant    1000098
# Name: count, dtype: int64

# %%
# ----------------------------
# 3. Overall Loss Ratio
# ----------------------------
print("\n3️⃣ Overall Loss Ratio:")
print(results["overall_loss_ratio"])
# Out:
# 3️⃣ Overall Loss Ratio:
# 1.0477452570332206

# %%
# ----------------------------
# 4. Grouped Loss Ratios
# ----------------------------
print("\nLoss Ratio by Province:")
print(results["grouped_loss_ratio_province"].head())

print("\nLoss Ratio by VehicleType:")
print(results["grouped_loss_ratio_vehicle"].head())

print("\nLoss Ratio by Gender:")
print(results["grouped_loss_ratio_gender"].head())
# Out:
# Loss Ratio by Province:
#                 TotalClaims  TotalPremium  LossRatio
# Province
# Gauteng        2.939415e+07  2.405377e+07   1.222018
# KwaZulu-Natal  1.430138e+07  1.320908e+07   1.082693
# Western Cape   1.038977e+07  9.806559e+06   1.059472
# North West     5.920250e+06  7.490508e+06   0.790367
# Mpumalanga     2.044675e+06  2.836292e+06   0.720897
#
# Loss Ratio by VehicleType:
#                     TotalClaims  TotalPremium  LossRatio
# VehicleType
# Heavy Commercial   7.504746e+05  4.609479e+05   1.628112
# Medium Commercial  4.119867e+06  3.922746e+06   1.050251
# Passenger Vehicle  5.937207e+07  5.664202e+07   1.048198
# Light Commercial   6.045250e+04  2.604975e+05   0.232066
# Bus                7.996535e+03  5.824474e+04   0.137292
#
# Loss Ratio by Gender:
#                 TotalClaims  TotalPremium  LossRatio
# Gender
# Not specified  6.271410e+07  5.920275e+07   1.059311
# Male           1.396704e+06  1.580143e+06   0.883910
# Female         2.502461e+05  3.044806e+05   0.821879

# %%
# ----------------------------
# 5. Outliers
# ----------------------------
print("\nOutliers in key numeric columns:")
for col, out in results["outliers"].items():
    print(f"{col}: {len(out)} outliers")
# Out:
# Outliers in key numeric columns:
# TotalClaims: 2793 outliers
# CustomValueEstimate: 1785 outliers

# %%
# ----------------------------
# 6. Monthly Trends
# ----------------------------
print("\nMonthly Trends (first 5 rows):")
print(results["monthly_trends"].head())
# Out:
# Monthly Trends (first 5 rows):
#                   TotalPremium   TotalClaims  PolicyCount  ClaimFrequency  \
# TransactionMonth
# 2013-10-31          371.063512      0.000000           45        0.000000
# 2013-11-30        21307.467009  50585.078947         1196       42.295217
# 2013-12-31        42484.748888   9283.385965         1495        6.209623
# 2014-01-31        54085.196865  12436.859649         1827        6.807258
# 2014-02-28        60788.436470  62989.307018         2062       30.547676
#
#                   ClaimSeverity
# TransactionMonth
# 2013-10-31             0.000000
# 2013-11-30             2.374054
# 2013-12-31             0.218511
# 2014-01-31             0.229949
# 2014-02-28             1.036205

# %%
# ----------------------------
# 7. Correlations
# ----------------------------
print("\nCorrelation Matrix:")
print(results["correlations"])
# Out:
# Correlation Matrix:
#                           UnderwrittenCoverID  PolicyID  PostalCode    mmcode  \
# UnderwrittenCoverID                  1.000000  0.916324   -0.018206  0.083310
# PolicyID                             0.916324  1.000000   -0.034186  0.074428
# PostalCode                          -0.018206 -0.034186    1.000000  0.100995
# mmcode                               0.083310  0.074428    0.100995  1.000000
# RegistrationYear                     0.065886  0.067192    0.009472 -0.088748
# Cylinders                           -0.026910 -0.028551   -0.042656 -0.100871
# cubiccapacity                        0.084892  0.088083   -0.139570  0.196766
# kilowatts                           -0.038613 -0.032198   -0.195637  0.033500
# NumberOfDoors                       -0.023781 -0.031438    0.083857  0.021488
# CustomValueEstimate                  0.006728  0.005268   -0.014861 -0.003286
# SumInsured                           0.003022  0.002141    0.001549 -0.010734
# CalculatedPremiumPerTerm             0.028029  0.025191    0.016138 -0.003154
# TotalPremium                         0.065413  0.059572    0.007394  0.012419
# TotalClaims                          0.003011  0.002941    0.000412 -0.000615
#
#                           RegistrationYear  Cylinders  cubiccapacity  \
# UnderwrittenCoverID               0.065886  -0.026910       0.084892
# PolicyID                          0.067192  -0.028551       0.088083
# PostalCode                        0.009472  -0.042656      -0.139570
# mmcode                           -0.088748  -0.100871       0.196766
# RegistrationYear                  1.000000  -0.034001       0.096951
# Cylinders                        -0.034001   1.000000       0.301620
# cubiccapacity                     0.096951   0.301620       1.000000
# kilowatts                         0.176013   0.325936       0.566559
# NumberOfDoors                     0.068109  -0.259174      -0.298624
# CustomValueEstimate               0.148682   0.018561       0.046180
# SumInsured                        0.003872   0.001635      -0.002233
# CalculatedPremiumPerTerm          0.065814   0.017942       0.038396
# TotalPremium                      0.058666   0.006826       0.042554
# TotalClaims                       0.005197   0.000043       0.001228
#
#                           kilowatts  NumberOfDoors  CustomValueEstimate  \
# UnderwrittenCoverID       -0.038613      -0.023781             0.006728
# PolicyID                  -0.032198      -0.031438             0.005268
# PostalCode                -0.195637       0.083857            -0.014861
# mmcode                     0.033500       0.021488            -0.003286
# RegistrationYear           0.176013       0.068109             0.148682
# Cylinders                  0.325936      -0.259174             0.018561
# cubiccapacity              0.566559      -0.298624             0.046180
# kilowatts                  1.000000      -0.115124             0.035497
# NumberOfDoors             -0.115124       1.000000            -0.054761
# CustomValueEstimate        0.035497      -0.054761             1.000000
# SumInsured                -0.002167      -0.000277            -0.000213
# CalculatedPremiumPerTerm   0.039054      -0.006545             0.019607
# TotalPremium               0.035024      -0.008002             0.019965
# TotalClaims                0.003099       0.001700             0.000853
#
#                           SumInsured  CalculatedPremiumPerTerm  TotalPremium  \
# UnderwrittenCoverID         0.003022                  0.028029      0.065413
# PolicyID                    0.002141                  0.025191      0.059572
# PostalCode                  0.001549                  0.016138      0.007394
# mmcode                     -0.010734                 -0.003154      0.012419
# RegistrationYear            0.003872                  0.065814      0.058666
# Cylinders                   0.001635                  0.017942      0.006826
# cubiccapacity              -0.002233                  0.038396      0.042554
# kilowatts                  -0.002167                  0.039054      0.035024
# NumberOfDoors              -0.000277                 -0.006545     -0.008002
# CustomValueEstimate        -0.000213                  0.019607      0.019965
# SumInsured                  1.000000                 -0.032294     -0.041174
# CalculatedPremiumPerTerm   -0.032294                  1.000000      0.635987
# TotalPremium               -0.041174                  0.635987      1.000000
# TotalClaims                -0.005129                  0.079787      0.121588
#
#                           TotalClaims
# UnderwrittenCoverID          0.003011
# PolicyID                     0.002941
# PostalCode                   0.000412
# mmcode                      -0.000615
# RegistrationYear             0.005197
# Cylinders                    0.000043
# cubiccapacity                0.001228
# kilowatts                    0.003099
# NumberOfDoors                0.001700
# CustomValueEstimate          0.000853
# SumInsured                  -0.005129
# CalculatedPremiumPerTerm     0.079787
# TotalPremium                 0.121588
# TotalClaims                  1.000000

# %%
# ----------------------------
# 8. Zip Code Aggregates
# ----------------------------
print("\nZip Code Aggregates (first 5 rows):")
print(results["zip_code_aggregates"])
# Out:
# Zip Code Aggregates (first 5 rows):
#              TotalPremium    TotalClaims
# PostalCode
# 1           273035.326595  307583.342105
# 2            60861.729133   61885.298246
# 4             8773.975714       0.000000
# 5            24661.450526   82951.526316
# 6            22260.230088    8628.596491
# ...                   ...            ...
# 9781         35077.787598   89698.245614
# 9830          7378.610100       0.000000
# 9868         11604.237719       0.000000
# 9869         63355.830081    2236.842105
# 9870         17703.244175       0.000000
#
# [888 rows x 2 columns]

# %%
# ----------------------------
# 9. Geographic Trends
# ----------------------------
print("\nGeographic Trends by Province (first 5 rows):")
print(results["geographic_trends"]["Province"])

print("\nGeographic Trends by CoverType (first 5 rows):")
print(results["geographic_trends"]["CoverType"])

print("\nGeographic Trends by Make (first 5 rows):")
print(results["geographic_trends"]["make"])
# Out:
# Geographic Trends by Province (first 5 rows):
#                TotalPremium   TotalClaims  PolicyCount
# Province
# Eastern Cape   2.140104e+06  1.356427e+06        30336
# Free State     5.213632e+05  3.549223e+05         8099
# Gauteng        2.405377e+07  2.939415e+07       393865
# KwaZulu-Natal  1.320908e+07  1.430138e+07       169781
# Limpopo        1.537324e+06  1.016477e+06        24836
# Mpumalanga     2.836292e+06  2.044675e+06        52718
# North West     7.490508e+06  5.920250e+06       143287
# Northern Cape  3.165581e+05  8.949051e+04         6380
# Western Cape   9.806559e+06  1.038977e+07       170796
#
# Geographic Trends by CoverType (first 5 rows):
#                                                     TotalPremium  \
# CoverType
# Accidental Death                                    7.619557e+05
# Asset Value Preserver                               2.472168e+04
# Baggage/Luggage                                     2.167058e+03
# Basic Excess Waiver                                 2.777227e+06
# Cash Takings                                        2.351160e+03
# Cleaning and Removal of Accident Debris             3.214261e+05
# Credit Protection                                   1.846776e+06
# Deposit Cover                                       6.683530e+04
# Emergency Charges                                   3.214868e+05
# Factory Fitted Sound and Other Electronic Equip...  0.000000e+00
# Fire and Theft                                      5.274990e+04
# Income Protector                                    2.973254e+06
# Keys and Alarms                                     2.143247e+05
# Own Damage                                          3.739605e+07
# Passenger Liability                                 3.024482e+05
# Roadside Assistance                                 3.448589e+04
# Signage and Vehicle Wraps                           1.071463e+05
# Standalone passenger liability                      2.227948e+04
# Third Party                                         1.338727e+07
# Third Party Only                                    6.773302e+03
# Trailer                                             1.131155e+03
# Windscreen                                          1.288699e+06
#
#                                                      TotalClaims  PolicyCount
# CoverType
# Accidental Death                                    0.000000e+00        27321
# Asset Value Preserver                               0.000000e+00          865
# Baggage/Luggage                                     0.000000e+00          172
# Basic Excess Waiver                                 0.000000e+00        57769
# Cash Takings                                        0.000000e+00          291
# Cleaning and Removal of Accident Debris             0.000000e+00       102414
# Credit Protection                                   3.325894e+05        18070
# Deposit Cover                                       4.385965e+04         1299
# Emergency Charges                                   1.641032e+04       102416
# Factory Fitted Sound and Other Electronic Equip...  2.109474e+04            3
# Fire and Theft                                      0.000000e+00          375
# Income Protector                                    2.565459e+06        64813
# Keys and Alarms                                     7.565853e+03       102428
# Own Damage                                          5.900945e+07       104183
# Passenger Liability                                 0.000000e+00       104158
# Roadside Assistance                                 3.344096e+03         3834
# Signage and Vehicle Wraps                           0.000000e+00       102416
# Standalone passenger liability                      0.000000e+00          544
# Third Party                                         1.582010e+06       102825
# Third Party Only                                    0.000000e+00           63
# Trailer                                             0.000000e+00           76
# Windscreen                                          1.285766e+06       103763
#
# Geographic Trends by Make (first 5 rows):
#                                      TotalPremium   TotalClaims  PolicyCount
# make
# AUDI                                 3.762743e+05  1.021004e+06         7407
# B.A.W                                1.660440e+05  2.871375e+05         2160
# BMW                                  2.427652e+05  4.814972e+05         5317
# C.A.M                                6.075631e+05  6.957082e+05        16171
# CHERY                                1.710593e+04  0.000000e+00          361
# CHEVROLET                            2.998058e+04  8.222474e+03          912
# CITROEN                              1.677549e+04  0.000000e+00          561
# CMC                                  9.574460e+05  1.323616e+06        21624
# DAIHATSU                             4.385965e+01  0.000000e+00            1
# FIAT                                 1.046168e+05  1.068876e+05          984
# FORD                                 2.110635e+04  2.040474e+03          427
# FORD                                 8.815716e+03  0.000000e+00          242
# FOTON                                1.437477e+05  1.214726e+04         3482
# GEELY                                1.125050e+04  0.000000e+00          108
# GOLDEN JOURNEY                       1.462989e+06  1.246583e+06        14462
# HINO                                 6.009224e+03  0.000000e+00          242
# HONDA                                5.086038e+03  0.000000e+00          130
# HUMMER                               9.519425e+04  0.000000e+00         1194
# HYUNDAI                              1.136156e+05  4.533079e+05         2602
# IVECO                                5.261262e+05  7.558930e+05         8430
# JINBEI                               5.516990e+05  3.407896e+05        10374
# JINBEI                               5.268779e+03  0.000000e+00           60
# JMC                                  5.635786e+03  2.300218e+04          120
# KIA                                  2.099326e+04  0.000000e+00          244
# LEXUS                                1.266839e+04  0.000000e+00          336
# MAHINDRA                             8.771930e+01  0.000000e+00            2
# MARCOPOLO                            2.665651e+03  7.996535e+03           51
# MAZDA                                1.877476e+04  2.064592e+04          418
# MERCEDES-BENZ                        2.764734e+06  2.938695e+06        41940
# MERCEDES-BENZ                        2.724330e+05  2.385554e+05         3131
# MITSUBISHI                           8.028528e+03  2.378596e+03          260
# NISSAN                               1.557737e+05  5.124100e+04         5462
# NISSAN/DATSUN                        9.210853e+05  3.735745e+05        10997
# OPEL                                 4.548667e+03  0.000000e+00          147
# PEUGEOT                              3.962651e+04  0.000000e+00          463
# POLARSUN                             4.102940e+04  1.251978e+05          934
# PROTON                               8.017889e+03  0.000000e+00          198
# RENAULT                              9.670554e+03  0.000000e+00          156
# SAIC                                 5.815291e+04  1.133360e+04          614
# SCANIA                               3.321484e+04  0.000000e+00          342
# SUZUKI                               2.701257e+04  1.712109e+05          408
# TATA                                 2.463595e+04  0.000000e+00          381
# TOYOTA                               4.994567e+07  5.174611e+07       813280
# TOYOTA                               7.610934e+04  2.690876e+04         1166
# VOLKSWAGEN                           1.416877e+06  1.839180e+06        20929
# VOLVO                                7.485233e+03  0.000000e+00          316

# %%
# ----------------------------
# 10. Vehicle Claims Summary
# ----------------------------
print("\nTop/Bottom Vehicle Claims by Make:")
print(results["vehicle_claims_summary"]["make"])
# Out:
# Top/Bottom Vehicle Claims by Make:
# {'lowest': make
# CITROEN                                0.0
# CHERY                                  0.0
# FORD                                   0.0
# DAIHATSU                               0.0
# GEELY                                  0.0
# Name: TotalClaims, dtype: float64, 'highest': make
# SUZUKI                                 419.634546
# JMC                                    191.684795
# HYUNDAI                                174.215195
# MARCOPOLO                              156.794806
# AUDI                                   137.843083
# Name: TotalClaims, dtype: float64}

# %% [markdown]
# ## Visualizations

# %%
visualizer = InsuranceEDAVisualizer(df_cleaned)

# %%
# Univariate distributions
visualizer.plot_univariate()
# Out:
# c:\Users\amare\Documents\KAIM\week-3\insurance_analytics\src\eda_visualizations.py:46: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])

# %%
# Bivariate / correlations
visualizer.plot_bivariate()

# %%
# Temporal trends (monthly claims/premium)
visualizer.plot_temporal_trends()
# Out:
# c:\Users\amare\Documents\KAIM\week-3\insurance_analytics\src\eda.py:72: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample("M")

# %%
# Loss ratio by Province, VehicleType, Gender
visualizer.plot_loss_ratio("Province")
visualizer.plot_loss_ratio("VehicleType")
visualizer.plot_loss_ratio("Gender")

# %%
# Vehicle claims top/bottom by Make and Model
visualizer.plot_vehicle_claims(top_n=10)

# %%
# Optional: automatic top 3 insights
visualizer.plot_top_insights()
# Out:
# c:\Users\amare\Documents\KAIM\week-3\insurance_analytics\src\eda.py:72: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample("M")
